# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the dataset
df=pd.read_csv('dataset.csv')

# %%
print(df.head())
# Out:
#                Name  Age  Gender Current educational level  Monthly Income  \
# 0    Aaron Roberson   24    Male             Undergraduate             582
# 1         Adam Ross   27    Male               High School             928
# 2      Alexa Ramsey   22  Female                  Graduate             519
# 3        Alexa Wade   21  Female             Undergraduate             567
# 4  Alexander Miller   29    Male                  Graduate             713
#
#    Rent/Room Accommodation  Utilities  Groceries  Dining Out/Eating Outside  \
# 0                      783         59         71                         63
# 1                      546         53        196                         31
# 2                      605         52        168                         83
# 3                      592         60         75                         83
# 4                      779         64        150                         87
#
#    Public Transportation  ...  Online Courses/Subscriptions  Clothing/Shoes  \
# 0                    149  ...                            57              56
# 1                    195  ...                            30              57
# 2                    165  ...                            48             106
# 3                    195  ...                            79              88
# 4                    165  ...                            18              92
#
#    Entertainment  Health Insurance/Medical Expenses  \
# 0             70                                159
# 1             63                                 22
# 2            120                                111
# 3            106                                126
# 4            174                                176
#
#    Gym Memberships/Physical Activities  Mobile Phone/Internet Bill  \
# 0                                   91                          33
# 1                                   46                          40
# 2                                   80                          46
# 3                                   37                          25
# 4                                   76                          45
#
#    Final Monthly Expense  Unnamed: 20  Unnamed: 21  %spending on Rent
# 0                   3794          NaN       23.515          20.637849
# 1                   3111          NaN       29.000                NaN
# 2                   6241          NaN       18.000                NaN
# 3                   3584          NaN     6712.000                NaN
# 4                   4439          NaN          NaN                NaN
#
# [5 rows x 23 columns]

# %%
#size of dataset
df.shape
# Out:
# (200, 23)

# %%
#information of dataset:
print("\nInformation:\n")
print(df.describe())
# Out:
# Information:
#
#               Age  Monthly Income  Rent/Room Accommodation   Utilities  \
# count  200.000000      200.000000               200.000000  200.000000
# mean    23.515000      906.090000               648.520000   59.085000
# std      3.583852      215.835881                92.402547    5.459561
# min     18.000000      503.000000               502.000000   50.000000
# 25%     20.000000      742.500000               560.750000   55.000000
# 50%     24.000000      911.000000               642.500000   58.000000
# 75%     27.000000     1087.500000               739.250000   63.250000
# max     29.000000     1292.000000               799.000000   69.000000
#
#         Groceries  Dining Out/Eating Outside  Public Transportation  \
# count  200.000000                 200.000000             200.000000
# mean   124.950000                  58.575000             150.580000
# std     41.798361                  22.051661              27.780793
# min     50.000000                  20.000000             101.000000
# 25%     91.750000                  41.000000             127.000000
# 50%    125.000000                  59.000000             153.500000
# 75%    158.000000                  75.750000             174.000000
# max    198.000000                  99.000000             199.000000
#
#        Fuel/Car Maintenance  Tuition Fees  Books and Supplies  \
# count            200.000000    200.000000          200.000000
# mean              58.155000   3076.550000           69.705000
# std               23.376339   1148.760205           27.990989
# min               20.000000   1002.000000           20.000000
# 25%               37.000000   2083.250000           46.750000
# 50%               55.500000   3033.000000           68.000000
# 75%               80.000000   4143.750000           92.250000
# max               99.000000   4988.000000          119.000000
#
#        Online Courses/Subscriptions  Clothing/Shoes  Entertainment  \
# count                    200.000000      200.000000     200.000000
# mean                      53.855000       82.765000     121.955000
# std                       25.939512       37.554513      41.455952
# min                       10.000000       20.000000      50.000000
# 25%                       31.000000       52.750000      89.000000
# 50%                       53.000000       82.500000     121.000000
# 75%                       77.250000      117.000000     158.000000
# max                       99.000000      148.000000     197.000000
#
#        Health Insurance/Medical Expenses  Gym Memberships/Physical Activities  \
# count                         200.000000                           200.000000
# mean                          108.425000                            55.620000
# std                            51.388992                            26.144854
# min                            20.000000                            10.000000
# 25%                            67.000000                            32.000000
# 50%                           108.000000                            56.500000
# 75%                           152.000000                            78.000000
# max                           198.000000                            99.000000
#
#        Mobile Phone/Internet Bill  Final Monthly Expense  Unnamed: 20  \
# count                  200.000000             200.000000          0.0
# mean                    44.030000            4712.770000          NaN
# std                     14.371213            1179.808743          NaN
# min                     20.000000            2466.000000          NaN
# 25%                     32.000000            3688.750000          NaN
# 50%                     42.500000            4697.000000          NaN
# 75%                     57.000000            5713.250000          NaN
# max                     69.000000            6712.000000          NaN
#
#        Unnamed: 21  %spending on Rent
# count     4.000000           1.000000
# mean   1695.628750          20.637849
# std    3344.250515                NaN
# min      18.000000          20.637849
# 25%      22.136250          20.637849
# 50%      26.257500          20.637849
# 75%    1699.750000          20.637849
# max    6712.000000          20.637849

# %%
#adding a new column of Sorted Names Alphabatically:
df['Sorted_Name']=sorted(df['Name'])
print(df)
# Out:
#                  Name  Age  Gender Current educational level  Monthly Income  \
# 0      Aaron Roberson   24    Male             Undergraduate             582
# 1           Adam Ross   27    Male               High School             928
# 2        Alexa Ramsey   22  Female                  Graduate             519
# 3          Alexa Wade   21  Female             Undergraduate             567
# 4    Alexander Miller   29    Male                  Graduate             713
# ..                ...  ...     ...                       ...             ...
# 195         Troy Kent   24    Male                  Graduate             771
# 196     Tyler Perkins   22    Male                  Graduate            1106
# 197  Wayne Fitzgerald   21    Male               High School            1027
# 198    Whitney Mosley   18  Female             Undergraduate            1077
# 199    William Mathis   27    Male                  Graduate            1104
#
#      Rent/Room Accommodation  Utilities  Groceries  Dining Out/Eating Outside  \
# 0                        783         59         71                         63
# 1                        546         53        196                         31
# 2                        605         52        168                         83
# 3                        592         60         75                         83
# 4                        779         64        150                         87
# ..                       ...        ...        ...                        ...
# 195                      673         67         93                         66
# 196                      638         63        169                         78
# 197                      759         69         75                         88
# 198                      741         67        172                         72
# 199                      621         55        111                         64
#
#      Public Transportation  ...  Clothing/Shoes  Entertainment  \
# 0                      149  ...              56             70
# 1                      195  ...              57             63
# 2                      165  ...             106            120
# 3                      195  ...              88            106
# 4                      165  ...              92            174
# ..                     ...  ...             ...            ...
# 195                    120  ...             141            168
# 196                    135  ...             121            133
# 197                    112  ...              72            113
# 198                    191  ...             119             51
# 199                    171  ...              77            134
#
#      Health Insurance/Medical Expenses  Gym Memberships/Physical Activities  \
# 0                                  159                                   91
# 1                                   22                                   46
# 2                                  111                                   80
# 3                                  126                                   37
# 4                                  176                                   76
# ..                                 ...                                  ...
# 195                                130                                   80
# 196                                 71                                   89
# 197                                166                                   74
# 198                                 39                                   36
# 199                                175                                   73
#
#      Mobile Phone/Internet Bill  Final Monthly Expense  Unnamed: 20  \
# 0                            33                   3794          NaN
# 1                            40                   3111          NaN
# 2                            46                   6241          NaN
# 3                            25                   3584          NaN
# 4                            45                   4439          NaN
# ..                          ...                    ...          ...
# 195                          35                   5949          NaN
# 196                          33                   4216          NaN
# 197                          67                   6509          NaN
# 198                          24                   5513          NaN
# 199                          25                   3860          NaN
#
#      Unnamed: 21  %spending on Rent       Sorted_Name
# 0         23.515          20.637849    Aaron Roberson
# 1         29.000                NaN         Adam Ross
# 2         18.000                NaN      Alexa Ramsey
# 3       6712.000                NaN        Alexa Wade
# 4            NaN                NaN  Alexander Miller
# ..           ...                ...               ...
# 195          NaN                NaN         Troy Kent
# 196          NaN                NaN     Tyler Perkins
# 197          NaN                NaN  Wayne Fitzgerald
# 198          NaN                NaN    Whitney Mosley
# 199          NaN                NaN    William Mathis
#
# [200 rows x 24 columns]

# %%
#calclate average age:
avg_age=df["Age"].mean()
print(f"Average Age:{avg_age}")
# Out:
# Average Age:23.515

# %%
#calculating Maxium age:
max_age=df["Age"].max()
print(f"Maximum age:{max_age}")
# Out:
# Maximum age:29

# %%
#Calculating minimum age:
min_age=df["Age"].min()
print(f"Minimum age:{min_age}")
# Out:
# Minimum age:18

# %%
#Adding a new column by sorting age:
df['Sorted_Age']=sorted(df['Age'])
print(df)

# %%
#counting number of males and females:
print(df['Gender'].value_counts())
df['Is_Male']=(df['Gender']=='Male').astype(int)
df['Is_Female']=(df['Gender']=='Female').astype(int)
print(df)
# Out:
# Gender
# Male      106
# Female     94
# Name: count, dtype: int64
#                  Name  Age  Gender Current educational level  Monthly Income  \
# 0      Aaron Roberson   24    Male             Undergraduate             582
# 1           Adam Ross   27    Male               High School             928
# 2        Alexa Ramsey   22  Female                  Graduate             519
# 3          Alexa Wade   21  Female             Undergraduate             567
# 4    Alexander Miller   29    Male                  Graduate             713
# ..                ...  ...     ...                       ...             ...
# 195         Troy Kent   24    Male                  Graduate             771
# 196     Tyler Perkins   22    Male                  Graduate            1106
# 197  Wayne Fitzgerald   21    Male               High School            1027
# 198    Whitney Mosley   18  Female             Undergraduate            1077
# 199    William Mathis   27    Male                  Graduate            1104
#
#      Rent/Room Accommodation  Utilities  Groceries  Dining Out/Eating Outside  \
# 0                        783         59         71                         63
# 1                        546         53        196                         31
# 2                        605         52        168                         83
# 3                        592         60         75                         83
# 4                        779         64        150                         87
# ..                       ...        ...        ...                        ...
# 195                      673         67         93                         66
# 196                      638         63        169                         78
# 197                      759         69         75                         88
# 198                      741         67        172                         72
# 199                      621         55        111                         64
#
#      Public Transportation  ...  Health Insurance/Medical Expenses  \
# 0                      149  ...                                159
# 1                      195  ...                                 22
# 2                      165  ...                                111
# 3                      195  ...                                126
# 4                      165  ...                                176
# ..                     ...  ...                                ...
# 195                    120  ...                                130
# 196                    135  ...                                 71
# 197                    112  ...                                166
# 198                    191  ...                                 39
# 199                    171  ...                                175
#
#      Gym Memberships/Physical Activities  Mobile Phone/Internet Bill  \
# 0                                     91                          33
# 1                                     46                          40
# 2                                     80                          46
# 3                                     37                          25
# 4                                     76                          45
# ..                                   ...                         ...
# 195                                   80                          35
# 196                                   89                          33
# 197                                   74                          67
# 198                                   36                          24
# 199                                   73                          25
#
#      Final Monthly Expense  Unnamed: 20  Unnamed: 21  %spending on Rent  \
# 0                     3794          NaN       23.515          20.637849
# 1                     3111          NaN       29.000                NaN
# 2                     6241          NaN       18.000                NaN
# 3                     3584          NaN     6712.000                NaN
# 4                     4439          NaN          NaN                NaN
# ..                     ...          ...          ...                ...
# 195                   5949          NaN          NaN                NaN
# 196                   4216          NaN          NaN                NaN
# 197                   6509          NaN          NaN                NaN
# 198                   5513          NaN          NaN                NaN
# 199                   3860          NaN          NaN                NaN
#
#           Sorted_Name  Is_Male  Is_Female
# 0      Aaron Roberson        1          0
# 1           Adam Ross        1          0
# 2        Alexa Ramsey        0          1
# 3          Alexa Wade        0          1
# 4    Alexander Miller        1          0
# ..                ...      ...        ...
# 195         Troy Kent        1          0
# 196     Tyler Perkins        1          0
# 197  Wayne Fitzgerald        1          0
# 198    Whitney Mosley        0          1
# 199    William Mathis        1          0
#
# [200 rows x 26 columns]

# %%
#count of current educational level:
print(df['Current educational level'].value_counts())
df['Is_Graduate']=(df['Current educational level']=='Graduate').astype(int)
df['Is_Undergraduate']=(df['Current educational level']=='Undergraduate').astype(int)
df['Is_HighSchool']=(df['Current educational level']=='High School').astype(int)
print(df)
# Out:
# Current educational level
# Graduate         77
# High School      75
# Undergraduate    48
# Name: count, dtype: int64
#                  Name  Age  Gender Current educational level  Monthly Income  \
# 0      Aaron Roberson   24    Male             Undergraduate             582
# 1           Adam Ross   27    Male               High School             928
# 2        Alexa Ramsey   22  Female                  Graduate             519
# 3          Alexa Wade   21  Female             Undergraduate             567
# 4    Alexander Miller   29    Male                  Graduate             713
# ..                ...  ...     ...                       ...             ...
# 195         Troy Kent   24    Male                  Graduate             771
# 196     Tyler Perkins   22    Male                  Graduate            1106
# 197  Wayne Fitzgerald   21    Male               High School            1027
# 198    Whitney Mosley   18  Female             Undergraduate            1077
# 199    William Mathis   27    Male                  Graduate            1104
#
#      Rent/Room Accommodation  Utilities  Groceries  Dining Out/Eating Outside  \
# 0                        783         59         71                         63
# 1                        546         53        196                         31
# 2                        605         52        168                         83
# 3                        592         60         75                         83
# 4                        779         64        150                         87
# ..                       ...        ...        ...                        ...
# 195                      673         67         93                         66
# 196                      638         63        169                         78
# 197                      759         69         75                         88
# 198                      741         67        172                         72
# 199                      621         55        111                         64
#
#      Public Transportation  ...  Final Monthly Expense  Unnamed: 20  \
# 0                      149  ...                   3794          NaN
# 1                      195  ...                   3111          NaN
# 2                      165  ...                   6241          NaN
# 3                      195  ...                   3584          NaN
# 4                      165  ...                   4439          NaN
# ..                     ...  ...                    ...          ...
# 195                    120  ...                   5949          NaN
# 196                    135  ...                   4216          NaN
# 197                    112  ...                   6509          NaN
# 198                    191  ...                   5513          NaN
# 199                    171  ...                   3860          NaN
#
#      Unnamed: 21  %spending on Rent       Sorted_Name  Is_Male  Is_Female  \
# 0         23.515          20.637849    Aaron Roberson        1          0
# 1         29.000                NaN         Adam Ross        1          0
# 2         18.000                NaN      Alexa Ramsey        0          1
# 3       6712.000                NaN        Alexa Wade        0          1
# 4            NaN                NaN  Alexander Miller        1          0
# ..           ...                ...               ...      ...        ...
# 195          NaN                NaN         Troy Kent        1          0
# 196          NaN                NaN     Tyler Perkins        1          0
# 197          NaN                NaN  Wayne Fitzgerald        1          0
# 198          NaN                NaN    Whitney Mosley        0          1
# 199          NaN                NaN    William Mathis        1          0
#
#      Is_Graduate  Is_Undergraduate  Is_HighSchool
# 0              0                 1              0
# 1              0                 0              1
# 2              1                 0              0
# 3              0                 1              0
# 4              1                 0              0
# ..           ...               ...            ...
# 195            1                 0              0
# 196            1                 0              0
# 197            0                 0              1
# 198            0                 1              0
# 199            1                 0              0
#
# [200 rows x 29 columns]

# %%
#Calulating Highest Spending category for each student:
df['Highest_Spending']=df[['Rent/Room Accommodation','Utilities','Groceries','Dining Out/Eating Outside','Public Transportation','Fuel/Car Maintenance','Tuition Fees','Books and Supplies','Online Courses/Subscriptions','Clothing/Shoes','Entertainment','Health Insurance/Medical Expenses','Gym Memberships/Physical Activities','Mobile Phone/Internet Bill']].idxmax(axis=1)
print(df)
# Out:
#                  Name  Age  Gender Current educational level  Monthly Income  \
# 0      Aaron Roberson   24    Male             Undergraduate             582
# 1           Adam Ross   27    Male               High School             928
# 2        Alexa Ramsey   22  Female                  Graduate             519
# 3          Alexa Wade   21  Female             Undergraduate             567
# 4    Alexander Miller   29    Male                  Graduate             713
# ..                ...  ...     ...                       ...             ...
# 195         Troy Kent   24    Male                  Graduate             771
# 196     Tyler Perkins   22    Male                  Graduate            1106
# 197  Wayne Fitzgerald   21    Male               High School            1027
# 198    Whitney Mosley   18  Female             Undergraduate            1077
# 199    William Mathis   27    Male                  Graduate            1104
#
#      Rent/Room Accommodation  Utilities  Groceries  Dining Out/Eating Outside  \
# 0                        783         59         71                         63
# 1                        546         53        196                         31
# 2                        605         52        168                         83
# 3                        592         60         75                         83
# 4                        779         64        150                         87
# ..                       ...        ...        ...                        ...
# 195                      673         67         93                         66
# 196                      638         63        169                         78
# 197                      759         69         75                         88
# 198                      741         67        172                         72
# 199                      621         55        111                         64
#
#      Public Transportation  ...  Unnamed: 20  Unnamed: 21  %spending on Rent  \
# 0                      149  ...          NaN       23.515          20.637849
# 1                      195  ...          NaN       29.000                NaN
# 2                      165  ...          NaN       18.000                NaN
# 3                      195  ...          NaN     6712.000                NaN
# 4                      165  ...          NaN          NaN                NaN
# ..                     ...  ...          ...          ...                ...
# 195                    120  ...          NaN          NaN                NaN
# 196                    135  ...          NaN          NaN                NaN
# 197                    112  ...          NaN          NaN                NaN
# 198                    191  ...          NaN          NaN                NaN
# 199                    171  ...          NaN          NaN                NaN
#
#           Sorted_Name  Is_Male  Is_Female  Is_Graduate  Is_Undergraduate  \
# 0      Aaron Roberson        1          0            0                 1
# 1           Adam Ross        1          0            0                 0
# 2        Alexa Ramsey        0          1            1                 0
# 3          Alexa Wade        0          1            0                 1
# 4    Alexander Miller        1          0            1                 0
# ..                ...      ...        ...          ...               ...
# 195         Troy Kent        1          0            1                 0
# 196     Tyler Perkins        1          0            1                 0
# 197  Wayne Fitzgerald        1          0            0                 0
# 198    Whitney Mosley        0          1            0                 1
# 199    William Mathis        1          0            1                 0
#
#      Is_HighSchool  Highest_Spending
# 0                0      Tuition Fees
# 1                1      Tuition Fees
# 2                0      Tuition Fees
# 3                0      Tuition Fees
# 4                0      Tuition Fees
# ..             ...               ...
# 195              0      Tuition Fees
# 196              0      Tuition Fees
# 197              1      Tuition Fees
# 198              0      Tuition Fees
# 199              0      Tuition Fees
#
# [200 rows x 30 columns]

# %%
#calculating highest spending student:
i=df['Final Monthly Expense'].idxmax()
print(f"Highest Spending Student:{df['Name'][i]}")
# Out:
# Highest Spending Student:Jake Russo

# %%
#Average Spending on Each category:
avg_spending=df[['Rent/Room Accommodation','Utilities','Groceries','Dining Out/Eating Outside','Public Transportation','Fuel/Car Maintenance','Tuition Fees','Books and Supplies','Online Courses/Subscriptions','Clothing/Shoes','Entertainment','Health Insurance/Medical Expenses','Gym Memberships/Physical Activities','Mobile Phone/Internet Bill']].mean()    
print(avg_spending)
# Out:
# Rent/Room Accommodation                 648.520
# Utilities                                59.085
# Groceries                               124.950
# Dining Out/Eating Outside                58.575
# Public Transportation                   150.580
# Fuel/Car Maintenance                     58.155
# Tuition Fees                           3076.550
# Books and Supplies                       69.705
# Online Courses/Subscriptions             53.855
# Clothing/Shoes                           82.765
# Entertainment                           121.955
# Health Insurance/Medical Expenses       108.425
# Gym Memberships/Physical Activities      55.620
# Mobile Phone/Internet Bill               44.030
# dtype: float64

# %%
#Spending by Gender:
print(df.groupby('Gender')['Final Monthly Expense'].mean())
# Out:
# Gender
# Female    4602.063830
# Male      4810.943396
# Name: Final Monthly Expense, dtype: float64

# %%
#category wise total:
category_total=df[['Rent/Room Accommodation','Utilities','Groceries','Dining Out/Eating Outside','Public Transportation','Fuel/Car Maintenance','Tuition Fees','Books and Supplies','Online Courses/Subscriptions','Clothing/Shoes','Entertainment','Health Insurance/Medical Expenses','Gym Memberships/Physical Activities','Mobile Phone/Internet Bill']].sum()
print(f"category wise toal:{category_total}")
# Out:
# category wise toal:Rent/Room Accommodation                129704
# Utilities                               11817
# Groceries                               24990
# Dining Out/Eating Outside               11715
# Public Transportation                   30116
# Fuel/Car Maintenance                    11631
# Tuition Fees                           615310
# Books and Supplies                      13941
# Online Courses/Subscriptions            10771
# Clothing/Shoes                          16553
# Entertainment                           24391
# Health Insurance/Medical Expenses       21685
# Gym Memberships/Physical Activities     11124
# Mobile Phone/Internet Bill               8806
# dtype: int64

# %%
#total spendings:
total_spending=category_total.sum()
print(f"Total Spendings: {total_spending}")
# Out:
# Total Spendings: 942554

# %%
#percentage of spendings:
Percentage=(category_total/total_spending)*100
print(f"Percentage Spendings:{Percentage}")
# Out:
# Percentage Spendings:Rent/Room Accommodation                13.760909
# Utilities                               1.253721
# Groceries                               2.651307
# Dining Out/Eating Outside               1.242900
# Public Transportation                   3.195149
# Fuel/Car Maintenance                    1.233988
# Tuition Fees                           65.281140
# Books and Supplies                      1.479066
# Online Courses/Subscriptions            1.142746
# Clothing/Shoes                          1.756186
# Entertainment                           2.587756
# Health Insurance/Medical Expenses       2.300664
# Gym Memberships/Physical Activities     1.180198
# Mobile Phone/Internet Bill              0.934270
# dtype: float64

# %%
#calculate correlation:
correlation=df.select_dtypes(include='number').corr()
print(f"Correlations:{correlation}")
# Out:
# Correlations:                                          Age  Monthly Income  \
# Age                                  1.000000       -0.007992
# Monthly Income                      -0.007992        1.000000
# Rent/Room Accommodation             -0.035942        0.016258
# Utilities                            0.011877        0.020024
# Groceries                            0.029089       -0.100594
# Dining Out/Eating Outside            0.019761       -0.077966
# Public Transportation                0.015205       -0.012643
# Fuel/Car Maintenance                -0.033468        0.065732
# Tuition Fees                        -0.051258       -0.036850
# Books and Supplies                   0.095196       -0.035602
# Online Courses/Subscriptions        -0.040004        0.012898
# Clothing/Shoes                       0.071843       -0.124022
# Entertainment                        0.051737       -0.096963
# Health Insurance/Medical Expenses   -0.051972        0.056788
# Gym Memberships/Physical Activities  0.023229        0.053016
# Mobile Phone/Internet Bill           0.080289       -0.064753
# Final Monthly Expense               -0.046861       -0.043587
# Unnamed: 20                               NaN             NaN
# Unnamed: 21                         -0.628904       -0.289695
# %spending on Rent                         NaN             NaN
# Is_Male                              0.015161        0.111744
# Is_Female                           -0.015161       -0.111744
# Is_Graduate                         -0.007631        0.011744
# Is_Undergraduate                    -0.035107       -0.004476
# Is_HighSchool                        0.038641       -0.007855
#
#                                      Rent/Room Accommodation  Utilities  \
# Age                                                -0.035942   0.011877
# Monthly Income                                      0.016258   0.020024
# Rent/Room Accommodation                             1.000000   0.107322
# Utilities                                           0.107322   1.000000
# Groceries                                          -0.019714  -0.082735
# Dining Out/Eating Outside                          -0.063306  -0.013848
# Public Transportation                              -0.145386   0.032441
# Fuel/Car Maintenance                               -0.018384   0.025962
# Tuition Fees                                        0.024428   0.049712
# Books and Supplies                                 -0.045297  -0.035480
# Online Courses/Subscriptions                       -0.024250  -0.087734
# Clothing/Shoes                                     -0.019749   0.133819
# Entertainment                                       0.045701   0.116269
# Health Insurance/Medical Expenses                  -0.003430  -0.059898
# Gym Memberships/Physical Activities                -0.116185  -0.012165
# Mobile Phone/Internet Bill                         -0.070639  -0.021744
# Final Monthly Expense                               0.092717   0.061956
# Unnamed: 20                                              NaN        NaN
# Unnamed: 21                                        -0.253214   0.653333
# %spending on Rent                                        NaN        NaN
# Is_Male                                             0.055636   0.148986
# Is_Female                                          -0.055636  -0.148986
# Is_Graduate                                         0.013708  -0.080275
# Is_Undergraduate                                    0.032267  -0.028119
# Is_HighSchool                                      -0.042244   0.105491
#
#                                      Groceries  Dining Out/Eating Outside  \
# Age                                   0.029089                   0.019761
# Monthly Income                       -0.100594                  -0.077966
# Rent/Room Accommodation              -0.019714                  -0.063306
# Utilities                            -0.082735                  -0.013848
# Groceries                             1.000000                   0.056676
# Dining Out/Eating Outside             0.056676                   1.000000
# Public Transportation                -0.038633                   0.002160
# Fuel/Car Maintenance                 -0.009383                   0.023827
# Tuition Fees                          0.067946                   0.062709
# Books and Supplies                   -0.012636                   0.067441
# Online Courses/Subscriptions         -0.021540                   0.066535
# Clothing/Shoes                        0.075850                   0.068137
# Entertainment                        -0.031629                   0.019647
# Health Insurance/Medical Expenses    -0.030431                   0.073607
# Gym Memberships/Physical Activities  -0.086618                   0.089032
# Mobile Phone/Internet Bill           -0.009743                   0.015786
# Final Monthly Expense                 0.096789                   0.088551
# Unnamed: 20                                NaN                        NaN
# Unnamed: 21                          -0.546792                   0.487652
# %spending on Rent                          NaN                        NaN
# Is_Male                               0.036594                   0.046022
# Is_Female                            -0.036594                  -0.046022
# Is_Graduate                           0.029784                   0.151226
# Is_Undergraduate                     -0.009154                  -0.129121
# Is_HighSchool                        -0.021860                  -0.038090
#
#                                      Public Transportation  \
# Age                                               0.015205
# Monthly Income                                   -0.012643
# Rent/Room Accommodation                          -0.145386
# Utilities                                         0.032441
# Groceries                                        -0.038633
# Dining Out/Eating Outside                         0.002160
# Public Transportation                             1.000000
# Fuel/Car Maintenance                             -0.021326
# Tuition Fees                                      0.055004
# Books and Supplies                                0.034671
# Online Courses/Subscriptions                     -0.041688
# Clothing/Shoes                                    0.173346
# Entertainment                                     0.108355
# Health Insurance/Medical Expenses                -0.044567
# Gym Memberships/Physical Activities               0.012150
# Mobile Phone/Internet Bill                       -0.027608
# Final Monthly Expense                             0.071339
# Unnamed: 20                                            NaN
# Unnamed: 21                                       0.554063
# %spending on Rent                                      NaN
# Is_Male                                           0.048631
# Is_Female                                        -0.048631
# Is_Graduate                                       0.021262
# Is_Undergraduate                                  0.095970
# Is_HighSchool                                    -0.106033
#
#                                      Fuel/Car Maintenance  Tuition Fees  \
# Age                                             -0.033468     -0.051258
# Monthly Income                                   0.065732     -0.036850
# Rent/Room Accommodation                         -0.018384      0.024428
# Utilities                                        0.025962      0.049712
# Groceries                                       -0.009383      0.067946
# Dining Out/Eating Outside                        0.023827      0.062709
# Public Transportation                           -0.021326      0.055004
# Fuel/Car Maintenance                             1.000000      0.020519
# Tuition Fees                                     0.020519      1.000000
# Books and Supplies                               0.128093     -0.094722
# Online Courses/Subscriptions                     0.088321      0.116180
# Clothing/Shoes                                   0.029429      0.079287
# Entertainment                                   -0.001388      0.119175
# Health Insurance/Medical Expenses                0.038998      0.052139
# Gym Memberships/Physical Activities             -0.112892      0.150012
# Mobile Phone/Internet Bill                       0.093579     -0.038581
# Final Monthly Expense                            0.044289      0.993251
# Unnamed: 20                                           NaN           NaN
# Unnamed: 21                                     -0.411716     -0.287218
# %spending on Rent                                     NaN           NaN
# Is_Male                                          0.029030      0.077824
# Is_Female                                       -0.029030     -0.077824
# Is_Graduate                                     -0.000412      0.013636
# Is_Undergraduate                                -0.026831      0.020450
# Is_HighSchool                                    0.024084     -0.031746
#
#                                      Books and Supplies  ...  \
# Age                                            0.095196  ...
# Monthly Income                                -0.035602  ...
# Rent/Room Accommodation                       -0.045297  ...
# Utilities                                     -0.035480  ...
# Groceries                                     -0.012636  ...
# Dining Out/Eating Outside                      0.067441  ...
# Public Transportation                          0.034671  ...
# Fuel/Car Maintenance                           0.128093  ...
# Tuition Fees                                  -0.094722  ...
# Books and Supplies                             1.000000  ...
# Online Courses/Subscriptions                   0.117369  ...
# Clothing/Shoes                                -0.072805  ...
# Entertainment                                  0.100180  ...
# Health Insurance/Medical Expenses             -0.038362  ...
# Gym Memberships/Physical Activities            0.040538  ...
# Mobile Phone/Internet Bill                     0.009429  ...
# Final Monthly Expense                         -0.064923  ...
# Unnamed: 20                                         NaN  ...
# Unnamed: 21                                   -0.758588  ...
# %spending on Rent                                   NaN  ...
# Is_Male                                        0.026289  ...
# Is_Female                                     -0.026289  ...
# Is_Graduate                                   -0.012986  ...
# Is_Undergraduate                               0.066736  ...
# Is_HighSchool                                 -0.045821  ...
#
#                                      Mobile Phone/Internet Bill  \
# Age                                                    0.080289
# Monthly Income                                        -0.064753
# Rent/Room Accommodation                               -0.070639
# Utilities                                             -0.021744
# Groceries                                             -0.009743
# Dining Out/Eating Outside                              0.015786
# Public Transportation                                 -0.027608
# Fuel/Car Maintenance                                   0.093579
# Tuition Fees                                          -0.038581
# Books and Supplies                                     0.009429
# Online Courses/Subscriptions                           0.099292
# Clothing/Shoes                                         0.013300
# Entertainment                                         -0.056063
# Health Insurance/Medical Expenses                      0.194960
# Gym Memberships/Physical Activities                    0.019731
# Mobile Phone/Internet Bill                             1.000000
# Final Monthly Expense                                 -0.020075
# Unnamed: 20                                                 NaN
# Unnamed: 21                                           -0.810195
# %spending on Rent                                           NaN
# Is_Male                                               -0.074902
# Is_Female                                              0.074902
# Is_Graduate                                            0.043503
# Is_Undergraduate                                      -0.047727
# Is_HighSchool                                         -0.001621
#
#                                      Final Monthly Expense  Unnamed: 20  \
# Age                                              -0.046861          NaN
# Monthly Income                                   -0.043587          NaN
# Rent/Room Accommodation                           0.092717          NaN
# Utilities                                         0.061956          NaN
# Groceries                                         0.096789          NaN
# Dining Out/Eating Outside                         0.088551          NaN
# Public Transportation                             0.071339          NaN
# Fuel/Car Maintenance                              0.044289          NaN
# Tuition Fees                                      0.993251          NaN
# Books and Supplies                               -0.064923          NaN
# Online Courses/Subscriptions                      0.139504          NaN
# Clothing/Shoes                                    0.113024          NaN
# Entertainment                                     0.153152          NaN
# Health Insurance/Medical Expenses                 0.090718          NaN
# Gym Memberships/Physical Activities               0.157262          NaN
# Mobile Phone/Internet Bill                       -0.020075          NaN
# Final Monthly Expense                             1.000000          NaN
# Unnamed: 20                                            NaN          NaN
# Unnamed: 21                                      -0.285870          NaN
# %spending on Rent                                      NaN          NaN
# Is_Male                                           0.088585          NaN
# Is_Female                                        -0.088585          NaN
# Is_Graduate                                       0.022507          NaN
# Is_Undergraduate                                  0.025348          NaN
# Is_HighSchool                                    -0.044983          NaN
#
#                                      Unnamed: 21  %spending on Rent   Is_Male  \
# Age                                    -0.628904                NaN  0.015161
# Monthly Income                         -0.289695                NaN  0.111744
# Rent/Room Accommodation                -0.253214                NaN  0.055636
# Utilities                               0.653333                NaN  0.148986
# Groceries                              -0.546792                NaN  0.036594
# Dining Out/Eating Outside               0.487652                NaN  0.046022
# Public Transportation                   0.554063                NaN  0.048631
# Fuel/Car Maintenance                   -0.411716                NaN  0.029030
# Tuition Fees                           -0.287218                NaN  0.077824
# Books and Supplies                     -0.758588                NaN  0.026289
# Online Courses/Subscriptions            0.834013                NaN -0.033154
# Clothing/Shoes                          0.304855                NaN  0.051055
# Entertainment                           0.391424                NaN  0.105328
# Health Insurance/Medical Expenses       0.244012                NaN  0.002335
# Gym Memberships/Physical Activities    -0.678698                NaN -0.023709
# Mobile Phone/Internet Bill             -0.810195                NaN -0.074902
# Final Monthly Expense                  -0.285870                NaN  0.088585
# Unnamed: 20                                  NaN                NaN       NaN
# Unnamed: 21                             1.000000                NaN -0.576399
# %spending on Rent                            NaN                NaN       NaN
# Is_Male                                -0.576399                NaN  1.000000
# Is_Female                               0.576399                NaN -1.000000
# Is_Graduate                            -0.334430                NaN -0.016676
# Is_Undergraduate                        0.577351                NaN -0.104149
# Is_HighSchool                          -0.332238                NaN  0.108639
#
#                                      Is_Female  Is_Graduate  Is_Undergraduate  \
# Age                                  -0.015161    -0.007631         -0.035107
# Monthly Income                       -0.111744     0.011744         -0.004476
# Rent/Room Accommodation              -0.055636     0.013708          0.032267
# Utilities                            -0.148986    -0.080275         -0.028119
# Groceries                            -0.036594     0.029784         -0.009154
# Dining Out/Eating Outside            -0.046022     0.151226         -0.129121
# Public Transportation                -0.048631     0.021262          0.095970
# Fuel/Car Maintenance                 -0.029030    -0.000412         -0.026831
# Tuition Fees                         -0.077824     0.013636          0.020450
# Books and Supplies                   -0.026289    -0.012986          0.066736
# Online Courses/Subscriptions          0.033154     0.044544         -0.006353
# Clothing/Shoes                       -0.051055    -0.059497          0.007276
# Entertainment                        -0.105328    -0.040139          0.035434
# Health Insurance/Medical Expenses    -0.002335     0.055181          0.041932
# Gym Memberships/Physical Activities   0.023709     0.173860         -0.005279
# Mobile Phone/Internet Bill            0.074902     0.043503         -0.047727
# Final Monthly Expense                -0.088585     0.022507          0.025348
# Unnamed: 20                                NaN          NaN               NaN
# Unnamed: 21                           0.576399    -0.334430          0.577351
# %spending on Rent                          NaN          NaN               NaN
# Is_Male                              -1.000000    -0.016676         -0.104149
# Is_Female                             1.000000     0.016676          0.104149
# Is_Graduate                           0.016676     1.000000         -0.444623
# Is_Undergraduate                      0.104149    -0.444623          1.000000
# Is_HighSchool                        -0.108639    -0.612870         -0.435286
#
#                                      Is_HighSchool
# Age                                       0.038641
# Monthly Income                           -0.007855
# Rent/Room Accommodation                  -0.042244
# Utilities                                 0.105491
# Groceries                                -0.021860
# Dining Out/Eating Outside                -0.038090
# Public Transportation                    -0.106033
# Fuel/Car Maintenance                      0.024084
# Tuition Fees                             -0.031746
# Books and Supplies                       -0.045821
# Online Courses/Subscriptions             -0.039167
# Clothing/Shoes                            0.053383
# Entertainment                             0.009085
# Health Insurance/Medical Expenses        -0.092454
# Gym Memberships/Physical Activities      -0.170090
# Mobile Phone/Internet Bill               -0.001621
# Final Monthly Expense                    -0.044983
# Unnamed: 20                                    NaN
# Unnamed: 21                              -0.332238
# %spending on Rent                              NaN
# Is_Male                                   0.108639
# Is_Female                                -0.108639
# Is_Graduate                              -0.612870
# Is_Undergraduate                         -0.435286
# Is_HighSchool                             1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# #Visualizations

# %%
#1. Pie chart for male female distribution:
categories=(["Males","Females"])
values=df['Gender'].value_counts()
colors=["blue","pink"]
plt.figure(figsize=(6,6))
plt.pie(values,labels=categories,autopct="%1.1f%%",colors=colors,shadow=True)
plt.title("Gender Distribution",fontsize=25,
                                fontweight="bold",
                                color="red")
plt.show()

# %%
#Count Plot for male female distribution:
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')
sns.countplot(x='Gender',data=df,color='darkblue')
plt.title("Gender Distribution",fontsize=25,
                                fontweight="bold",
                                color="red")
plt.show()

# %%
#2.Pie chart for current educational status distribution:
categories=(["Graduate","Undergraduate","Highschool"]) 
values=df['Current educational level'].value_counts()
colors=["red","green","yellow"] 
plt.figure(figsize=(6,6))
plt.pie(values,labels=categories,autopct="%1.1f%%",colors=colors,shadow=True)
plt.title("Current educational level distribution",fontsize=15,
                                                   fontweight="bold",
                                                   color="darkblue")
plt.show()

# %%
#count plot for current educational level distribution:  
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')
sns.countplot(x='Current educational level',data=df,color='darkblue') 
plt.title("Current educational level distribution",fontsize=15,
                                                   fontweight="bold",
                                                   color="black")
plt.show()

# %%
#3.countplot of highest spending catogiery for each student :
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')
sns.countplot(x='Highest_Spending',data=df,color='darkblue',linewidth=2,edgecolor='white')
plt.title("Highest Spending Catogiery For Each Student",fontsize=15,
                                                        fontweight="bold",
                                                        color="black") 
plt.show()

# %%
#4.bar plot for highest spending student with highest spender:
top=df.sort_values(by='Final Monthly Expense',ascending=False).head(10)
colors=['skyblue']*len(top)
colors[0]='red'
plt.figure(figsize=(8,4))
plt.barh(top['Name'],top['Final Monthly Expense'],color=colors)
plt.title("Top 10 Highest Spending Students (Highlighted)",fontsize=15,
                                                           fontweight="bold",
                                                           color="black") 
plt.xlabel("Names",fontsize=12,
                   fontweight="bold",
                   color="darkblue")                                                                                                                
plt.ylabel("Final Monthly Expenses",fontsize=12,
                                    fontweight="bold",
                                    color="darkblue") 
plt.yticks(fontsize=8)                                     
plt.show()

# %%
#Bar plot for catogory wise avg:
avg_spending=df[['Rent/Room Accommodation','Utilities','Groceries','Dining Out/Eating Outside','Public Transportation','Fuel/Car Maintenance','Tuition Fees','Books and Supplies','Online Courses/Subscriptions','Clothing/Shoes','Entertainment','Health Insurance/Medical Expenses','Gym Memberships/Physical Activities','Mobile Phone/Internet Bill']].mean().to_numpy()                                        
categories=np.array(['Rent/Room Accommodation','Utilities','Groceries','Dining Out/Eating Outside','Public Transportation','Fuel/Car Maintenance','Tuition Fees','Books and Supplies','Online Courses/Subscriptions','Clothing/Shoes','Entertainment','Health Insurance/Medical Expenses','Gym Memberships/Physical Activities','Mobile Phone/Internet Bill'])
plt.barh(categories,avg_spending,color='darkblue')
plt.title("Category wise Avg. spendings",fontsize=12,
                                         fontweight="bold",
                                         color="darkblue")
plt.xlabel('Categories',fontsize=12,
                         fontweight='bold',
                         color='black')  
plt.ylabel('Avg. Spendings',fontsize=12,
                            fontweight='bold',
                            color='black')  
plt.yticks(fontsize=5,rotation=45,ha='right')                             
plt.show()

# %%
#5.pie chart for spending by gender:
values=df.groupby('Gender')['Final Monthly Expense'].mean().to_numpy()
categories=(['spendings by male','spending by female'])
colors=['blue','pink']
plt.figure(figsize=(6,6))
plt.pie(values,labels=categories,autopct="%1.1f%%",colors=colors,shadow=True,startangle=45)
plt.title("Spendings By Gender",fontsize=25,
                                fontweight='bold',
                                color='red')  
plt.show()

# %%
#6.pie chart for percentage spending:
plt.figure(figsize=(10,10))

plt.pie(Percentage,autopct='%1.1f%%',
        startangle=90,labeldistance=1.1,pctdistance=0.8, shadow=True)

plt.title("Percentage Spending by Category", fontsize=14, fontweight='bold')
plt.legend(Percentage.index,loc="best")

plt.show()

# %%
#7.Heatmap for correlation:
plt.figure(figsize=(12,8))

sns.heatmap(correlation)

plt.title("Correlation Matrix", fontsize=25, fontweight='bold')
plt.xticks(fontsize=5)

plt.show()
